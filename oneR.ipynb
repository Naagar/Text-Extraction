# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('one.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)
for i in range(0,10):
    gray_im = cv2.erode(gray_im,kernel1,iterations = 1)
    
# orignal minus eroded
img = img - gray_im

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np

img = cv2.imread('one.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,10,
                            param1=50,param2=12,minRadius=0,maxRadius=20)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

plt.subplot(111),plt.imshow(cimg, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read
gray_im = cv2.imread('three.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)

# Noise removing 
gray_im = cv2.medianBlur(gray_im,5)
    

# Binary
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]

cv2.imwrite('Binary.png', gray_im)
img  = gray_im
img_orignal  = gray_im

# Erosion
kernel = np.ones((5,5),np.uint8)
gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    

# binary - eroded     
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)
fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
imgplot.set_clim(0.0, 0.7)
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Final')
cv2.imwrite('Final131.png', img)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('test1.png')

#orig = image.copy()
(H, W) = gray_im.shape[:2]
H = int(H/2)
W = int(W/2)

# resize the image and grab the new image dimensions
gray_im = cv2.resize(gray_im, (W, H))
(H, W) = image.shape[:2]

gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
gray_im = cv2.medianBlur(gray_im,5)
    


thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
    
kernel = np.ones((5,5),np.uint8)
#opening = cv2.morphologyEx(gray_im, cv2.MORPH_OPEN, kernel)
#gradient = cv2.morphologyEx(gray_im, cv2.MORPH_GRADIENT, kernel)

gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)


fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Test Result')
cv2.imwrite('Test11.png', img)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('test.png',0)


# resize
(H, W) = gray_im.shape[:2]
H = int(H/4)
W = int(W/4)
gray_im = cv2.resize(gray_im, (W, H))
(H, W) = gray_im.shape[:2]
print(H,W)

count = np.zeros(256)
for i in range(0,255):
    for j in range(0,H-1):
        for k in range(0,W-1):
            if gray_im[j][k] == i :
                count[i]+= 1

new_img = np.zeros(256,H,W)                 
for i in range(0,255):
    if count[i]>400:
        for j in range(0,H-1):
            for k in range(0,W-1):
                if  gray_im[j][k] == i:
                    new_img[i][j][k] = 255
                else:
                    new_img[i][j][k] = 0

connectivity = 8                    
output = cv2.connectedComponentsWithStats(thresh, connectivity, cv2.CV_32S)
            
        
        
                
                
print(count)

#gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)

plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()


cv2.imwrite('Test111.png', gray_im)
# Out:
# 734 495
# [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   1.00000000e+00   4.00000000e+00
#    0.00000000e+00   1.00000000e+00   3.00000000e+00   4.00000000e+00
#    4.00000000e+00   9.00000000e+00   1.20000000e+01   8.00000000e+00
#    1.20000000e+01   2.00000000e+01   1.50000000e+01   1.80000000e+01
#    2.00000000e+01   3.00000000e+01   2.70000000e+01   2.40000000e+01
#    3.00000000e+01   4.60000000e+01   3.90000000e+01   5.50000000e+01
#    6.00000000e+01   7.50000000e+01   6.00000000e+01   9.20000000e+01
#    1.00000000e+02   1.03000000e+02   1.05000000e+02   8.80000000e+01
#    9.40000000e+01   1.06000000e+02   1.38000000e+02   1.57000000e+02
#    2.07000000e+02   2.32000000e+02   3.25000000e+02   3.16000000e+02
#    4.16000000e+02   4.20000000e+02   4.89000000e+02   4.49000000e+02
#    4.79000000e+02   4.28000000e+02   4.21000000e+02   4.27000000e+02
#    4.94000000e+02   5.05000000e+02   6.97000000e+02   6.70000000e+02
#    9.53000000e+02   9.54000000e+02   8.58000000e+02   9.54000000e+02
#    8.89000000e+02   1.28200000e+03   1.24600000e+03   1.23400000e+03
#    1.71100000e+03   1.91900000e+03   1.77800000e+03   2.44500000e+03
#    2.81900000e+03   2.52300000e+03   3.40000000e+03   3.90700000e+03
#    3.34900000e+03   5.01700000e+03   6.04000000e+03   5.44100000e+03
