# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('four.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)
for i in range(0,10):
    gray_im = cv2.erode(gray_im,kernel1,iterations = 1)
    
# orignal minus eroded
img = img - gray_im

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np

img = cv2.imread('one.png',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,10,
                            param1=50,param2=12,minRadius=0,maxRadius=20)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

plt.subplot(111),plt.imshow(cimg, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read
gray_im = cv2.imread('three.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)

# Noise removing 
gray_im = cv2.medianBlur(gray_im,5)
    

# Binary
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]

cv2.imwrite('Binary.png', gray_im)
img  = gray_im
img_orignal  = gray_im

# Erosion
kernel = np.ones((5,5),np.uint8)
gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    

# binary - eroded     
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)
fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
imgplot.set_clim(0.0, 0.7)
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Final')
cv2.imwrite('Final131.png', img)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('test1.png')

#orig = image.copy()
(H, W) = gray_im.shape[:2]
H = int(H/2)
W = int(W/2)

# resize the image and grab the new image dimensions
gray_im = cv2.resize(gray_im, (W, H))
(H, W) = image.shape[:2]

gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
gray_im = cv2.medianBlur(gray_im,5)
    


thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
    
kernel = np.ones((5,5),np.uint8)
#opening = cv2.morphologyEx(gray_im, cv2.MORPH_OPEN, kernel)
#gradient = cv2.morphologyEx(gray_im, cv2.MORPH_GRADIENT, kernel)

gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)


fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Test Result')
cv2.imwrite('Test11.png', img)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('test.png',0)


# resize
(H, W) = gray_im.shape[:2]
H = int(H/4)
W = int(W/4)
gray_im = cv2.resize(gray_im, (W, H))
(H, W) = gray_im.shape[:2]
print(H,W)

count = np.zeros(256)
for i in range(0,255):
    for j in range(0,H-1):
        for k in range(0,W-1):
            if gray_im[j][k] == i :
                count[i]+= 1

new_img = np.zeros(256,H,W)                 
for i in range(0,255):
    if count[i]>400:
        for j in range(0,H-1):
            for k in range(0,W-1):
                if  gray_im[j][k] == i:
                    new_img[i][j][k] = 255
                else:
                    new_img[i][j][k] = 0

connectivity = 8                    
output = cv2.connectedComponentsWithStats(thresh, connectivity, cv2.CV_32S)
            
        
        
                
                
print(count)

#gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)

plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()


cv2.imwrite('Test111.png', gray_im)
# Out:
# 734 495
# [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   1.00000000e+00   4.00000000e+00
#    0.00000000e+00   1.00000000e+00   3.00000000e+00   4.00000000e+00
#    4.00000000e+00   9.00000000e+00   1.20000000e+01   8.00000000e+00
#    1.20000000e+01   2.00000000e+01   1.50000000e+01   1.80000000e+01
#    2.00000000e+01   3.00000000e+01   2.70000000e+01   2.40000000e+01
# ...

# %%
new_img = np.zeros((256,H,W))
print(np.shape(new_img))
# Out:
# (256, 734, 495)

# %%
import cv2

colorImage = imread('one.png')
I = rgb2gray(colorImage)

#% Detect MSER regions.
[mserRegions, mserConnComp] = detectMSERFeatures(I,'RegionAreaRange', [200 8000] , 'ThresholdDelta', 4 )

figure
imshow(I)
hold on
plot(mserRegions, 'showPixelList', true,'showEllipses',false)
title('MSER regions')
hold off
# Out:
#   File "<ipython-input-9-9dae513bbc75>", line 7
#     [mserRegions, mserConnComp] = detectMSERFeatures(I,'RegionAreaRange', [200 8000] , 'ThresholdDelta', 4 )
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


mser = cv2.MSER_create()


img = cv2.imread('one.png')


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

vis = img.copy()

#detect regions in gray scale image
regions, _ = mser.detectRegions(gray)

hulls = [cv2.convexHull(p.reshape(-1, 1, 2)) for p in regions]
cv2.polylines(vis, hulls, 1, (0, 255, 0))

plt.subplot(111),plt.imshow(vis)
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

mask = np.zeros((img.shape[0], img.shape[1], 1), dtype=np.uint8)

for contour in hulls:

    cv2.drawContours(mask, [contour], -1, (255, 255, 255), -1)

#this is used to find only text regions, remaining are ignored
text_only = cv2.bitwise_and(img, img, mask=mask)

#cv2.imshow("text only", text_only)
plt.subplot(111),plt.imshow(text_only)
plt.title('text only'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('four.png',0)
edges = cv2.Canny(img,20,20)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Canny edge

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('three.png',0)
edges = cv2.Canny(img,40,20)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


img1 = cv2.imread('one.png')
gray_image1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    
gray_image1 = cv2.medianBlur(gray_image1,5)


thresh = 127
im_bw1 = cv2.threshold(gray_image1, thresh, 255, cv2.THRESH_BINARY)[1]




kernel = np.ones((5,5),np.uint8)

erosion1 = cv2.erode(im_bw1,kernel,iterations = 2)
#cv2.imwrite('Binary_normal.png', erosion1)

erosion1 = cv2.Canny(erosion1,5,10)
print(erosion1)


plt.subplot(111),plt.imshow(erosion1, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

img_read = cv2.imread('one.png')

img_b,img_g,img_r = cv2.split(img_read)

img_r = cv2.Canny(img_r ,200,255)
img_g = cv2.Canny(img_g ,200,255)
img_b = cv2.Canny(img_b ,200,255)



[m,n] = np.shape(img_r)


img_copy = img_b | img_g | img_r


result = cv2.findContours(img_copy.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
contours, hierarchy = result if len(result) == 2 else result[1:3]

hierarchy = hierarchy[0]

keepers = []

for index_, contour_ in enumerate(contours):
    x, y, w, h = cv2.boundingRect(contour_)

    # Check the contour and it's bounding box
    if keep(contour_) and include_box(index_, hierarchy, contour_):
        # It's a winner!
        keepers.append([contour_, [x, y, w, h]])

new_image = edges.copy()
new_image.fill(255)
boxes = []

for index_, (contour_, box) in enumerate(keepers):

    # Find the average intensity of the edge pixels to
    # determine the foreground intensity
    fg_int = 0.0
    for p in contour_:
        fg_int += ii(p[0][0], p[0][1])

    fg_int /= len(contour_)
    # Find the intensity of three pixels going around the
    # outside of each corner of the bounding box to determine
    # the background intensity
    x_, y_, width, height = box
    bg_int = \
        [
            # bottom left corner 3 pixels
            ii(x_ - 1, y_ - 1),
            ii(x_ - 1, y_),
            ii(x_, y_ - 1),

            # bottom right corner 3 pixels
            ii(x_ + width + 1, y_ - 1),
            ii(x_ + width, y_ - 1),
            ii(x_ + width + 1, y_),

            # top left corner 3 pixels
            ii(x_ - 1, y_ + height + 1),
            ii(x_ - 1, y_ + height),
            ii(x_, y_ + height + 1),

            # top right corner 3 pixels
            ii(x_ + width + 1, y_ + height + 1),
            ii(x_ + width, y_ + height + 1),
            ii(x_ + width + 1, y_ + height)
        ]

    # Find the median of the background
    # pixels determined above
    bg_int = np.median(bg_int)

    
    # Determine if the box should be inverted
    if fg_int >= bg_int:
        fg = 255
        bg = 0
    else:
        fg = 0
        bg = 255

    # Loop through every pixel in the box and color the
        # pixel accordingly
    for x in range(x_, x_ + width):
        for y in range(y_, y_ + height):    
            if ii(x, y) > fg_int:
                new_image[y][x] = bg
            else:
                new_image[y][x] = fg

# blur a bit to improve ocr accuracy
new_image = cv2.blur(new_image, (2, 2))
cv2.imwrite(output_file, new_image)
















fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5),sharex=True, sharey=True)

ax1.imshow(img_r, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=17)

ax2.imshow(img_g, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=17)

ax3.imshow(img_copy, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=3$', fontsize=17)
fig.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
 

im_in = cv2.imread("two.png", cv2.IMREAD_GRAYSCALE)
 

th, im_th = cv2.threshold(im_in, 100, 250, cv2.THRESH_BINARY_INV)
 
# Copy the thresholded image.
im_floodfill = im_th.copy()
 
# Mask used to flood filling.
# Notice the size needs to be 2 pixels than the image.
h, w = im_th.shape[:2]
mask = np.zeros((h+2, w+2), np.uint8)
 
# Floodfill from point (0, 0)
cv2.floodFill(im_floodfill, mask, (0,0), 255)
 
# Invert floodfilled image
im_floodfill_inv = cv2.bitwise_not(im_floodfill)
 
# Combine the two images to get the foreground.
im_out = im_th | im_floodfill_inv
 
# Display images.

##cv2.imshow("Thresholded Image", im_th)
#cv2.imshow("Floodfilled Image", im_floodfill)
#cv2.imshow("Inverted Floodfilled Image", im_floodfill_inv)
#cv2.imshow("Foreground", im_out)
#cv2.waitKey(0)
img_sub = im_out - im_floodfill


fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=1, ncols=4, figsize=(10, 4),sharex=True, sharey=True)

ax1.imshow(im_th, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('Thresholded Image', fontsize=17)

ax2.imshow(im_floodfill, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Floodfilled Image', fontsize=17)

ax3.imshow(im_floodfill_inv, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Inverted Floodfilled Image', fontsize=17)

ax4.imshow(im_out, cmap=plt.cm.gray)
ax4.axis('off')
ax4.set_title('Foreground', fontsize=17)

fig.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
    
im_in = cv2.imread("one.png",1)

hsv = cv2.cvtColor(im_in, cv2.COLOR_BGR2HSV)
    
lower_red = np.array([30,150,50])
upper_red = np.array([255,255,180])
    
mask = cv2.inRange(hsv, lower_red, upper_red)
res = cv2.bitwise_and(im_in,im_in, mask= mask)

    
edges = cv2.Canny(im_in,100,200)
    
    
    
fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True,
                       figsize=(12, 5))

ax[0].imshow(im_in, cmap=plt.cm.gray)
ax[0].set_title('Input image')

ax[1].imshow(edges, cmap=plt.cm.gray)
ax[1].set_title('Canny Edge Detection')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Sobel Edge detection

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('one.jpg')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)
for i in range(0,10):
    gray_im = cv2.erode(gray_im,kernel1,iterations = 1)
    
# orignal minus eroded
img = img - gray_im


laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('three.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gaussian = cv2.GaussianBlur(gray,(3,3),0)

#canny
img_canny = cv2.Canny(img,100,200)

#sobel
img_sobelx = cv2.Sobel(img_gaussian,cv2.CV_8U,1,0,ksize=3)
img_sobely = cv2.Sobel(img_gaussian,cv2.CV_8U,0,1,ksize=3)
img_sobel = img_sobelx + img_sobely


#prewitt
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)
img_prewitt = img_prewitty + img_prewittx


plt.subplot(2,2,1),plt.imshow(img)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(img_canny,cmap = 'gray')
plt.title('Canny '), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(img_prewitt,cmap = 'gray')
plt.title('prewitt'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(img_sobel,cmap = 'gray')
plt.title('Sobel '), plt.xticks([]), plt.yticks([])

plt.show()


fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True,
                       figsize=(12, 5))

ax[0].imshow(img_canny, cmap=plt.cm.gray)
ax[0].set_title('Input image')

ax[1].imshow(img_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()
cv2.imwrite("SobelEdgeDetection.jpg", img_sobel)
# Out:
# True

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#roi is the object or region of object we need to find
roi = cv2.imread('three_thresh.jpg')
hsv = cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)

#target is the image we search in
target = cv2.imread('one.jpg')
hsvt = cv2.cvtColor(target,cv2.COLOR_BGR2HSV)

# Find the histograms using calcHist. Can be done with np.histogram2d also
M = cv2.calcHist([hsv],[0, 1], None, [180, 256], [0, 180, 0, 256] )
I = cv2.calcHist([hsvt],[0, 1], None, [180, 256], [0, 180, 0, 256] )

R = M/I


print(np.shape(M))

h,s,v = cv2.split(hsvt)
B = R[h.ravel(),s.ravel()]
B = np.minimum(B,1)
B = B.reshape(hsvt.shape[:2])
print(np.shape(B))


disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
cv2.filter2D(B,-1,disc,B)
B = np.uint8(B)
cv2.normalize(B,B,0,255,cv2.NORM_MINMAX)

ret,thresh = cv2.threshold(B,50,255,0)
#print(thresh,ret)

# Read Image
gray_im = cv2.imread('two.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh_ret = ret
gray_im = cv2.threshold(gray_im, ret, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)
for i in range(0,10):
    gray_im = cv2.erode(gray_im,kernel1,iterations = 1)
    
# orignal minus eroded
img = img - gray_im

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
cv2.imwrite("SobelEdgeDetection.jpg", img)
# Out:
# c:\users\naagar\anaconda3\envs\opencv-env\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in true_divide
# c:\users\naagar\anaconda3\envs\opencv-env\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide
# (180, 256)
# (2721, 1961)
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('two.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gaussian = cv2.GaussianBlur(gray,(3,3),0)

#canny
img_canny = cv2.Canny(img,100,200)

#sobel
img_sobelx = cv2.Sobel(img_gaussian,cv2.CV_8U,1,0,ksize=3)
img_sobely = cv2.Sobel(img_gaussian,cv2.CV_8U,0,1,ksize=3)
img_sobel = img_sobelx + img_sobely


#prewitt
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)
img_prewitt = img_prewitty + img_prewittx


plt.subplot(2,2,1),plt.imshow(img)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(img_canny,cmap = 'gray')
plt.title('Canny '), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(img_prewitt,cmap = 'gray')
plt.title('prewitt'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(img_sobel,cmap = 'gray')
plt.title('Sobel '), plt.xticks([]), plt.yticks([])

plt.show()


fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True,
                       figsize=(12, 5))

ax[0].imshow(img_canny, cmap=plt.cm.gray)
ax[0].set_title('Input image')

ax[1].imshow(img_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()
cv2.imwrite("SobelEdgeDetectionTwo.jpg", img_sobel)
# Out:
# True
