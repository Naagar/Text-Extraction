# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


img1 = cv2.imread('one.png')
gray_image1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    
gray_image1 = cv2.medianBlur(gray_image1,5)


thresh = 127
im_bw1 = cv2.threshold(gray_image1, thresh, 255, cv2.THRESH_BINARY)[1]

cv2.imwrite('Binary_normal.png', im_bw1)

kernel = np.ones((5,5),np.uint8)

erosion1 = cv2.erode(im_bw1,kernel,iterations = 2)


plt.subplot(111),plt.imshow(erosion1, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read image
img = cv2.imread('one.png')


# RGB to Gray
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Bluring image
for i in range(0,2):
    #print('skdjb')
    gray_image = cv2.medianBlur(gray_image,5)

# Gray to Binary
thresh = 127
im_bw = cv2.threshold(gray_image, thresh, 255, cv2.THRESH_BINARY)[1]

# Erosion
kernel = np.ones((5,5),np.uint8)
#for j in range(0,2):
#    im_bw = cv2.erode(im_bw,kernel,iterations = 1)
    
# Opening 
im_bw = cv2.morphologyEx(im_bw, cv2.MORPH_OPEN, kernel)
# Closing
im_bw = cv2.morphologyEx(im_bw, cv2.MORPH_CLOSE, kernel)


plt.subplot(111),plt.imshow(im_bw, cmap = 'gray')
plt.title('Result Image '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np;
im = cv2.imread('blob.jpg', cv2.IMREAD_GRAYSCALE)

thresh = 127
im = cv2.threshold(im, thresh, 255, cv2.THRESH_BINARY)[1]


# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()

# Change thresholds
params.minThreshold = 50
params.maxThreshold = 150
# Filter by Area.
params.filterByArea = True
params.minArea = 150
detector = cv2.SimpleBlobDetector_create(params)

# Detect blobs.
keypoints = detector.detect(im)

# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures
# the size of the circle corresponds to the size of blob

im_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (255,0,0), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)



plt.subplot(111),plt.imshow(im_with_keypoints, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
# Show blobs
#cv2.imshow("Keypoints", im_with_keypoints)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-721d8b226f70> in <module>()
#      38
#      39 # Detect blobs.
# ---> 40 keypoints = detector.detect(im)
#      41
#      42 # Draw detected blobs as red circles.
#
# TypeError: Incorrect type of self (must be 'Feature2D' or its derivative)

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('two.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
for i in range(0,5):
    gray_im = cv2.medianBlur(gray_im,5)

thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
    
kernel = np.ones((5,5),np.uint8)
for i in range(0,10):
    gray_im = cv2.erode(gray_im,kernel,iterations = 1)
    
img = img - gray_im


plt.subplot(131),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(132),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(133),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# #  top 21-10-18  16:24

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('three.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
gray_im = cv2.medianBlur(gray_im,5)
    


thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
    
kernel = np.ones((5,5),np.uint8)

gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)
fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
imgplot.set_clim(0.0, 0.7)
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Final')
cv2.imwrite('Final13.png', img)
# Out:
# True

# %%
'''plt.subplot(131),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(132),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()'''

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('one.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)

gray_im = cv2.erode(gray_im,kernel1,iterations = 8)
    
# orignal minus eroded
img = img - gray_im

# again erosion
                #kernel2 = np.ones((3,3),np.uint8)
img = cv2.erode(img,kernel1,iterations = 3)


# Dialation 
img = cv2.dilate(img,kernel1,iterations = 3)

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

cv2.imwrite('Final141.png', img)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('two.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)

gray_im = cv2.erode(gray_im,kernel1,iterations = 10)
    
# orignal minus eroded
img = img - gray_im

# again erosion
                #kernel2 = np.ones((3,3),np.uint8)
img = cv2.erode(img,kernel1,iterations = 4)


# Dialation 
img = cv2.dilate(img,kernel1,iterations = 2)

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('three.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)

gray_im = cv2.erode(gray_im,kernel1,iterations = 10)
    
# orignal minus eroded
img = img - gray_im

# again erosion
                #kernel2 = np.ones((3,3),np.uint8)`1
img = cv2.erode(img,kernel1,iterations = 4)


# Dialation 
img = cv2.dilate(img,kernel1,iterations = 2)

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Read Image
gray_im = cv2.imread('four.png')
gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
# Bluring 
gray_im = cv2.medianBlur(gray_im,5)
gray_im=cv2.GaussianBlur(gray_im, (3, 3), 0)

# Binary 
thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
# Erosion

kernel1 = np.ones((5,5),np.uint8)

gray_im = cv2.erode(gray_im,kernel1,iterations = 10)
    
# orignal minus eroded
img = img - gray_im

# again erosion
                #kernel2 = np.ones((3,3),np.uint8)
img = cv2.erode(img,kernel1,iterations = 4)


# Dialation 
img = cv2.dilate(img,kernel1,iterations = 2)

plt.subplot(111),plt.imshow(img_orignal, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(gray_im, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()


cv2.imwrite('Final of preprocessing FOUR.png', img)
# Out:
# True

# %%
import cv, cv2
fn = 'one.jpg'
im_gray = cv2.imread(fn, cv.CV_LOAD_IMAGE_GRAYSCALE)
im_gray_mat = cv.fromarray(im_gray)
im_bw = cv.CreateImage(cv.GetSize(im_gray_mat), cv.IPL_DEPTH_8U, 1);
im_bw_mat = cv.GetMat(im_bw)
threshold = 0 # 128#255# HAS NO EFFECT!?!?
cv.Threshold(im_gray_mat, im_bw_mat, threshold, 255, cv.CV_THRESH_BINARY | cv.CV_THRESH_OTSU);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-438393933d2a> in <module>()
# ----> 1 import cv, cv2
#       2 fn = 'one.jpg'
#       3 im_gray = cv2.imread(fn, cv.CV_LOAD_IMAGE_GRAYSCALE)
#       4 im_gray_mat = cv.fromarray(im_gray)
#       5 im_bw = cv.CreateImage(cv.GetSize(im_gray_mat), cv.IPL_DEPTH_8U, 1);
#
# ModuleNotFoundError: No module named 'cv'

# %%
import cv2
im_gray_ = cv2.imread('one.png', cv2.IMREAD_GRAYSCALE)


(thresh, im_bw_) = cv2.threshold(im_gray_, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)



im_bw_ = cv2.threshold(im_gray_, thresh, 255, cv2.THRESH_BINARY)[1]
plt.subplot(111),plt.imshow(im_bw_, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()


cv2.imwrite('Binary_by_OTSU.png', im_bw_)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('one.png')

#orig = image.copy()
(H, W) = gray_im.shape[:2]
H = int(H/2)
W = int(W/2)

# resize the image and grab the new image dimensions
#gray_im = cv2.resize(gray_im, (W, H))
#(H, W) = image.shape[:2]

gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
gray_im = cv2.medianBlur(gray_im,5)
    


thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
    
kernel = np.ones((5,5),np.uint8)
opening = cv2.morphologyEx(gray_im, cv2.MORPH_OPEN, kernel)
gradient = cv2.morphologyEx(gray_im, cv2.MORPH_GRADIENT, kernel)

gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)
fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
imgplot.set_clim(0.0, 0.7)
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Final')
cv2.imwrite('Final11111.png', img)
# Out:
# True

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


edges = cv2.Canny(gray,50,150,apertureSize = 3)

lines = cv2.HoughLines(edges,1,np.pi/180,200)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('houghlines3.jpg',img)

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("one.png")
#orig = image.copy()
(H, W) = image.shape[:2]
H = int(H/4)
W = int(W/4)

# resize the image and grab the new image dimensions
image = cv2.resize(image, (W, H))
(H, W) = image.shape[:2]


plt.subplot(111),plt.imshow(image, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


gray_im = cv2.imread('test1.png')

#orig = image.copy()
(H, W) = gray_im.shape[:2]
H = int(H/2)
W = int(W/2)

# resize the image and grab the new image dimensions
#gray_im = cv2.resize(gray_im, (W, H))
#(H, W) = image.shape[:2]

gray_im = cv2.cvtColor(gray_im, cv2.COLOR_BGR2GRAY)
gray_im = cv2.medianBlur(gray_im,5)
    


thresh = 127
gray_im = cv2.threshold(gray_im, thresh, 255, cv2.THRESH_BINARY)[1]
img  = gray_im
img_orignal  = gray_im
    
kernel = np.ones((5,5),np.uint8)
opening = cv2.morphologyEx(gray_im, cv2.MORPH_OPEN, kernel)
gradient = cv2.morphologyEx(gray_im, cv2.MORPH_GRADIENT, kernel)

gray_im = cv2.erode(gray_im,kernel,iterations = 10)
    
img = img - gray_im
# Dilation 
kernel1 = np.ones((3,3),np.uint8)
#img = cv2.dilate(img,kernel1,iterations = 1)
fig = plt.figure()
a = fig.add_subplot(1, 3, 1)
imgplot = plt.imshow(img_orignal, cmap = 'gray')
a.set_title('img_orignal')

a = fig.add_subplot(1, 3, 2)
imgplot = plt.imshow(gray_im, cmap = 'gray')
imgplot.set_clim(0.0, 0.7)
a.set_title('Intermediat')

a = fig.add_subplot(1, 3, 3)
imgplot = plt.imshow(img, cmap = 'gray')
a.set_title('Test Result')
cv2.imwrite('Test11.png', img)
# Out:
# True

# %% [markdown]
# # Gabor Filter

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt



g_kernel = cv2.getGaborKernel((30, 30), 16.0, np.pi/4, 20.0, 0.75, 0, ktype=cv2.CV_32F)

img = cv2.imread('three.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
filtered_img = cv2.filter2D(img, cv2.CV_8UC3, g_kernel)

#cv2.imshow('image', img)
#cv2.imshow('filtered image', filtered_img)

#h, w = g_kernel.shape[:2]
#g_kernel = cv2.resize(g_kernel, (3*w, 3*h), interpolation=cv2.INTER_CUBIC)

#g_kernel = cv2.getGaborKernel((21, 21), 8.0, np.pi/4, 10.0, 0.5, 0, ktype=cv2.CV_32F)

image_new =filtered_img - img 

plt.subplot(111),plt.imshow(img, cmap = 'gray')
plt.title('OrignalImage '), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(111),plt.imshow(filtered_img, cmap = 'gray')
plt.title('After Gabor filtering'), plt.xticks([]), plt.yticks([])
plt.show()

plt.subplot(111),plt.imshow(image_new, cmap = 'gray')
plt.title('After Gabor filtering'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


img1 = cv2.imread('one.png')
gray_image1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    
gray_image1 = cv2.medianBlur(gray_image1,5)


thresh = 127
im_bw1 = cv2.threshold(gray_image1, thresh, 255, cv2.THRESH_BINARY)[1]




kernel = np.ones((5,5),np.uint8)

erosion1 = cv2.erode(im_bw1,kernel,iterations = 2)
cv2.imwrite('Binary_normal.png', erosion1)

erosion1 = cv2.Canny(erosion1,5,10)


plt.subplot(111),plt.imshow(erosion1, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt


img1 = cv2.imread('one.png')
gray_image1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

    
gray_image1 = cv2.medianBlur(gray_image1,5)


thresh = 127
im_bw1 = cv2.threshold(gray_image1, thresh, 255, cv2.THRESH_BINARY)[1]




kernel = np.ones((5,5),np.uint8)

erosion1 = cv2.erode(im_bw1,kernel,iterations = 2)
#cv2.imwrite('Binary_normal.png', erosion1)

erosion1 = cv2.Canny(erosion1,5,10)


plt.subplot(111),plt.imshow(erosion1, cmap = 'gray')
plt.title('I-1 '), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage import feature


# Generate noisy image of a square
im = cv2.imread('one.png', 0)
#im[32:-32, 32:-32] = 1


#im = ndi.gaussian_filter(im, 3)



edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma= 2)


fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5),sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=15)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=15)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=3$', fontsize=15)
fig.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from skimage.data import camera
from skimage.filters import roberts, sobel, scharr, prewitt


image = cv2.imread('one.png',0)
edge_roberts = roberts(image)
edge_sobel = sobel(image)

fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True,
                       figsize=(8, 4))

ax[0].imshow(edge_roberts, cmap=plt.cm.gray)
ax[0].set_title('Roberts Edge Detection')

ax[1].imshow(edge_sobel, cmap=plt.cm.gray)
ax[1].set_title('Sobel Edge Detection')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

cv2.imwrite('Test11edge_roberts.png', edge_roberts)
cv2.imwrite('Test11edge_sobel.png', edge_sobel)
# Out:
# True

# %%
import numpy as np
from scipy.ndimage.filters import convolve, gaussian_filter
from scipy.misc import imread, imshow
import matplotlib.pyplot as plt
 
def CannyEdgeDetector(im, blur = 1, highThreshold = 91, lowThreshold = 31):
    im = np.array(im, dtype=float) #Convert to float to prevent clipping values
 
    #Gaussian blur to reduce noise
    im2 = gaussian_filter(im, blur)
 
    #Use sobel filters to get horizontal and vertical gradients
    im3h = convolve(im2,[[-1,0,1],[-2,0,2],[-1,0,1]]) 
    im3v = convolve(im2,[[1,2,1],[0,0,0],[-1,-2,-1]])
 
    #Get gradient and direction
    grad = np.power(np.power(im3h, 2.0) + np.power(im3v, 2.0), 0.5)
    theta = np.arctan2(im3v, im3h)
    thetaQ = (np.round(theta * (5.0 / np.pi)) + 5) % 5 #Quantize direction
 
    #Non-maximum suppression
    gradSup = grad.copy()
    for r in range(im.shape[0]):
        for c in range(im.shape[1]):
            #Suppress pixels at the image edge
            if r == 0 or r == im.shape[0]-1 or c == 0 or c == im.shape[1] - 1:
                gradSup[r, c] = 0
                continue
            tq = thetaQ[r, c] % 4
 
            if tq == 0: #0 is E-W (horizontal)
                if grad[r, c] <= grad[r, c-1] or grad[r, c] <= grad[r, c+1]:
                    gradSup[r, c] = 0
            if tq == 1: #1 is NE-SW
                if grad[r, c] <= grad[r-1, c+1] or grad[r, c] <= grad[r+1, c-1]:
                    gradSup[r, c] = 0
            if tq == 2: #2 is N-S (vertical)
                if grad[r, c] <= grad[r-1, c] or grad[r, c] <= grad[r+1, c]:
                    gradSup[r, c] = 0
            if tq == 3: #3 is NW-SE
                if grad[r, c] <= grad[r-1, c-1] or grad[r, c] <= grad[r+1, c+1]:
                    gradSup[r, c] = 0
 
    #Double threshold
    strongEdges = (gradSup > highThreshold)
 
    #Strong has value 2, weak has value 1
    thresholdedEdges = np.array(strongEdges, dtype=np.uint8) + (gradSup > lowThreshold)
 
    #Tracing edges with hysteresis	
    #Find weak edge pixels near strong edge pixels
    finalEdges = strongEdges.copy()
    currentPixels = []
    for r in range(1, im.shape[0]-1):
        for c in range(1, im.shape[1]-1):	
            if thresholdedEdges[r, c] != 1:
                continue #Not a weak pixel
 
            #Get 3x3 patch	
            localPatch = thresholdedEdges[r-1:r+2,c-1:c+2]
            patchMax = localPatch.max()
            if patchMax == 2:
                currentPixels.append((r, c))
                finalEdges[r, c] = 1
 
    #Extend strong edges based on current pixels
    while len(currentPixels) > 0:
        newPix = []
        for r, c in currentPixels:
            for dr in range(-1, 2):
                for dc in range(-1, 2):
                    if dr == 0 and dc == 0: continue
                    r2 = r+dr
                    c2 = c+dc
                    if thresholdedEdges[r2, c2] == 1 and finalEdges[r2, c2] == 0:
                        #Copy this weak pixel to final result
                        newPix.append((r2, c2))
                        finalEdges[r2, c2] = 1
        currentPixels = newPix
 
    return finalEdges
 
                        #Open image, convert to greyscale

im = cv2.imread("one.jpg", mode="L") 
finalEdges = CannyEdgeDetector(im)

fig, ax = plt.subplots(ncols=2, sharex=True, sharey=True,
                       figsize=(8, 4))

ax[0].imshow(im, cmap=plt.cm.gray)
ax[0].set_title('Image')

ax[1].imshow(finalEdges, cmap=plt.cm.gray)
ax[1].set_title('Edge Detection')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()
# Out:
# c:\users\naagar\anaconda3\envs\opencv-env\lib\site-packages\ipykernel_launcher.py:84: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
